# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def eng(N3):
    return (134.0*2 - 45*2)/(N3 - 12)

# %%
m = 2
N3 = np.linspace(20,80, 61)
m = eng(N3)
plt.scatter(N3,m)
plt.grid()

# %%
N2 =(45*2/m)-12
N2
# Out:
# array([-7.95505618, -7.4494382 , -6.94382022, -6.43820225, -5.93258427,
#        -5.42696629, -4.92134831, -4.41573034, -3.91011236, -3.40449438,
#        -2.8988764 , -2.39325843, -1.88764045, -1.38202247, -0.87640449,
#        -0.37078652,  0.13483146,  0.64044944,  1.14606742,  1.65168539,
#         2.15730337,  2.66292135,  3.16853933,  3.6741573 ,  4.17977528,
#         4.68539326,  5.19101124,  5.69662921,  6.20224719,  6.70786517,
#         7.21348315,  7.71910112,  8.2247191 ,  8.73033708,  9.23595506,
#         9.74157303, 10.24719101, 10.75280899, 11.25842697, 11.76404494,
#        12.26966292, 12.7752809 , 13.28089888, 13.78651685, 14.29213483,
#        14.79775281, 15.30337079, 15.80898876, 16.31460674, 16.82022472,
#        17.3258427 , 17.83146067, 18.33707865, 18.84269663, 19.34831461,
#        19.85393258, 20.35955056, 20.86516854, 21.37078652, 21.87640449,
#        22.38202247])

# %%
a = 60
b = np.linspace(115, 122,1000)
C = np.sqrt(a**2 + b**2)
plt.plot(b, C)

# %%
45*2/(12+22)
# Out:
# 2.6470588235294117

# %%
(135*2/(2.647))-22
# Out:
# 80.00226671703817
